# %% [markdown]
# # Глубинное обучение 1 / Введение в глубинное обучение, ФКН ВШЭ
#
# ## Домашнее задание 3: RNN и языковые модели
#
# ### Общая информация
#
# Оценка после штрафа после мягкого дедлайна вычисляется по формуле $M_{\text{penalty}} = M_{\text{full}} \cdot 0.85^{t/1440}$, где $M_{\text{full}}$ — полная оценка за работу без учета штрафа, а $t$ — время в минутах, прошедшее после мягкого дедлайна (округление до двух цифр после запятой). Таким образом, спустя первые сутки после мягкого дедлайна вы не можете получить оценку выше 12.75, а если сдать через четыре дня после мягкого дедлайна, то ваш максимум — 7.83 балла.
#
# ### Оценивание и штрафы
#
# Максимально допустимая оценка за работу — 15 баллов. Сдавать задание после указанного срока сдачи нельзя.
#
# Задание выполняется самостоятельно. «Похожие» решения считаются плагиатом и все задействованные студенты (в том числе те, у кого списали) не могут получить за него больше 0 баллов. Если вы нашли решение какого-то из заданий (или его часть) в открытом источнике, необходимо указать ссылку на этот источник в отдельном блоке в конце вашей работы (скорее всего вы будете не единственным, кто это нашел, поэтому чтобы исключить подозрение в плагиате, необходима ссылка на источник).
#
# Неэффективная реализация кода может негативно отразиться на оценке. Также оценка может быть снижена за плохо читаемый код и плохо оформленные графики. Все ответы должны сопровождаться кодом или комментариями о том, как они были получены.
#
# ### О задании
#
# В этом задании вам предстоит обучить рекуррентную нейронную сеть для задачи генерации текстов. В качестве данных возьмем набор из 120 тысяч анекдотов (всех категорий от А до Я включительно). Его вы можете найти в архиве `jokes.txt.zip`, который доступен по [ссылке](https://disk.yandex.com/d/fjt5xICH-ukEEA).

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Задание 1: Dataset (1 балл)
#
# В этом задании мы будет пользоваться библиотекой [sentencepiece](https://github.com/google/sentencepiece), которая поддерживает разные форматы токенизации текстов, в том числе BPE, который мы и будем использовать. Реализуйте недостающие фрагменты кода в классе `TextDataset` в файле `dataset.py`. Датасет обучает sentencepiece токенизатор, токенизирует тексты, превращает токены в индексы и паддит до одной и той же длины (параметр `max_length`). Не забудьте, что для генерации текстов нам будут нужны специальные токены начала и конца последовательности, соответственно `BOS` и `EOS`. Существуют еще два специальных токена &mdash; паддинг `PAD` и токен `UNK`, заменяющий out-of-vocabulary токены.

# %%
# !pip install sentencepiece
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 14.7 MB/s eta 0:00:00
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.97

# %%
import torch
import numpy as np
from dataset import TextDataset
from model import LanguageModel
from train import train
from torch.utils.data import DataLoader

# %%
train_set = TextDataset(data_file='jokes.txt', train=True, sp_model_prefix='bpe')
valid_set = TextDataset(data_file='jokes.txt', train=False, sp_model_prefix='bpe')

# %%
# Код должен проходить тесты
assert len(train_set) + len(valid_set) == 120759

for _ in range(5):
    for dataset in (train_set, valid_set):
        indices, length = dataset[np.random.randint(len(dataset))]
        assert indices.shape == (dataset.max_length, )
        assert indices[0].item() == dataset.bos_id
        assert (indices == dataset.eos_id).sum().item() == 1

        eos_pos = indices.tolist().index(dataset.eos_id)
        assert torch.all(indices[eos_pos + 1:] == dataset.pad_id)
        assert (indices != dataset.pad_id).sum() == length

# %% [markdown]
# ## Задание 2 Language model (3.5 балла)
#
# Реализуйте класс `LanguageModel` из файла `model.py`. Мы будем генерировать текст с помощью языковой модели &mdash; это авторегрессионная вероятностная модель, которая предсказывает распределение следующего токена при условии предыдущих:
#
# $$
# p(x_1, x_2, x_3, \dots, x_T) = p(x_1) \cdot p(x_2 | x_1) \cdot p(x_3|x_1, x_2) \, \cdot \, \dots \, \cdot \, p(x_T|x_1, \dots, x_{T-1})
# $$
#
# Мы будем реализовывать ее с помощью рекуррентной нейронной сети. Ваш код должен поддерживать возможность работать как с оригинальной [RNN](https://pytorch.org/docs/stable/generated/torch.nn.RNN.html#torch.nn.RNN), так и c [LSTM](https://bitly.com/98K8eH). На каждом временном шаге модель возвращает логиты вероятностей для следующего токена. Модель будет работать в двух режимах (не путать с `.train()` и `.eval()`):
#
# - В режиме обучения (метод `forward`) модель принимает настоящие последовательности из датасета и их длины. На каждом временном шаге возвращаются логиты вероятностей следующего токена, что позволяет считать лосс, обучаться на трейне и валидироваться на валидации.
#
# - В режиме генерации (инференса, метод `inference`) модель принимает некоторый префикс (возможно пустой), с которого начинать генерацию, и продолжает его. Для этого на каждом шаге генерируются новые логиты, семплируется новый токен (из распределения, заданного логитами), и процесс продолжается, пока не будет сгенерирован токен `EOS` или не будет достигнуто ограничение на длину последовательности. **Обратите внимание**, что вам не нужно прогонять всю последовательность заново через RNN после каждого нового токена, это приведет к квадратичной сложности по длине последовательности. Вам достаточно обновлять скрытое состояние, подавая на вход новый сгенерированный токен и предыдущее скрытое состояние. Кроме того, чтобы получить больше контроля над генерацией, вводится параметр температуры `temp`. Перед семплированием нужно разделить на него логиты, полученные моделью.

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cpu')

# %%
model_d = LanguageModel(train_set,  device=device).to(device)

# %%
# Код должен проходить тесты
for bs in [1, 4, 16, 64, 256]:
    indices = torch.randint(high=train_set.vocab_size, size=(bs, train_set.max_length))
    lengths = torch.randint(low=1, high=train_set.max_length + 1, size=(bs, ))
    logits = model_d(indices, lengths)
    assert logits.shape == (bs, lengths.max(), train_set.vocab_size)

for prefix in ['', 'купил мужик шляпу,', 'сел медведь в машину и', 'подумал штирлиц']:
    generated = model_d.inference(prefix, temp=np.random.uniform(0.1, 10))
    assert type(generated) == str
    assert generated.startswith(prefix)

# %% [markdown]
# ## Задание 3: Training (2 балла)
#
# Всё, что нам осталось &mdash; реализовать цикл обучения. Заполните пропуски в файле `train.py`. Не забудьте, что мы учим модель предсказывать вероятность следующего, а не текущего токена. Также рекомендуется обрезать батч индексов по самой длинной последовательности, чтобы не гонять паддинги вхолостую. Для оценки качества генерации будем использовать метрику [perplexity](https://towardsdatascience.com/perplexity-in-language-models-87a196019a94). Реализуйте ее подсчет в функции `plot_losses` (да, для этого достаточно только значения лосса).
#
# Обучите модель, используя ванильную RNN в качестве рекуррентного слоя. Сохраните чекпойнт обученной модели, он нам еще пригодится.

# %%
Epochs = 5
Samples = 4
Batch = 128

# %%
optimizer = torch.optim.Adam(model_d.parameters(), lr=1e-3, weight_decay=1e-6)
scheduler = torch.optim.lr_scheduler.LinearLR(optimizer)
ttrain = torch.utils.data.DataLoader(train_set, batch_size=Batch, shuffle=True)
ttest = torch.utils.data.DataLoader(valid_set, batch_size=Batch, shuffle=False)

# %%
train(model_d, optimizer, scheduler, ttrain, ttest, Epochs, Samples)
# Out:
# Generation examples:
# жителя женщину акку не дают, что населения наоборот, а даже сталот?- у кого ты проститутка, папа и черточный!- это просто такое?
# штирлиц сокзрите на двой могут везе, а начши книга, шуткой.
# - дорогой, мои штуард психолог? вон каполиво ртался гладитка...
# лек, украине лучше... вот есть дело у нас рабочислят, тем сильки ему говорят - значит, принято - ходит кокатеги пыке-ка повисимое мясо.

# %% [markdown]
# ## Задание 4: LSTM (0.5 балла)
#
# Обучите аналогичную модель, но с LSTM в качестве рекуррентного слоя. Сравните модели по метрикам и генерации. Не забывайте про чекпойнты!

# %%
model_d = LanguageModel(train_set, rnn_type=torch.nn.LSTM, device=device).to(device)
optimizer = torch.optim.Adam(model_d.parameters())
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=Epochs)
train_loader = DataLoader(train_set, batch_size=32, shuffle=True, num_workers=2, pin_memory=True)
val_loader = DataLoader(valid_set, batch_size=32, shuffle=False, num_workers=2, pin_memory=True)
train(model_d, optimizer, scheduler, train_loader, val_loader, Epochs)
torch.save(model_d, 'lstm_vanilla_adam')
# Out:
# Generation examples:
# показывают, я наступал свое бутылку? - ну, у нее есть на зеркало.
# хочется и психолога, устал кота на душу, по уходето с он можно идет рядом сборнем поддерными грани ними!
# - как вы колбиить мы вчера уже на уезд поганперастер вдмой, понимаете, а складывается?- да так? герожий же они трях- ну, что?жена меня будет забывает лицом.
# у тебя позволяет красные ограбиж заплатил никогда в носкоре другого!
# - папа, а у нас дома, на приеме больше милиция демократии? да приходит, и говорит сыри- - лягунгешки,!- а о! это ты этого венибудь дожили?

# %%
train_loader = DataLoader(train_set, batch_size=32, shuffle=True, num_workers=2, pin_memory=True)
val_loader = DataLoader(valid_set, batch_size=32, shuffle=False, num_workers=2, pin_memory=True)
train(model_d, optimizer, scheduler, train_loader, val_loader, 25)
# Out:
# Generation examples:
# сегодня я выйду, хватило фамилии котиков, во втором ведь на мосовой функ и понял.
# только только так некоторые так быстро, и все на вопрос - куда же леткуться до воракой, то это недовожает произносит.
# сначала зрительном приходится набухание - она общается только после шести про службу консервас.
# - в этом смышь, какие можно найти - весы сдать, в монплоудито уже отдельностью.- все лето.
# активирует своего начальнику уволил, победившие сиськи без проблем по легре, то можно просто нужна проиграет сапоран жильные эмоции.

# %%
model_d.inference('Штирлиц', temp=0.1)
# Out:
# 'штирлиц вышел из окна.'

# %%
model_d.inference('Абоба', temp=0.2)
# Out:
# 'абобатка, что у нас в россии не было, а не наоборот.'

# %% [markdown]
# ## Задание 5: Sampling temperature (0.5 балла)
#
# Поэкспериментируйте, как результат генерации зависит от параметра температуры. Попробуйте генерацию с разными префиксами. Сделайте выводы.

# %%
temps = np.linspace(0.1, 0.7, 3)
prefixes = ['Путин', 'Штирлиц', 'Как-то раз']
for temp in temps:
    print(f'temp = {temp}:')
    for prefix in prefixes:
        print(model_d.inference(prefix, temp))
        print('\n')
    print('\n')
# Out:
# temp = 0.1:
# путин пложает упасколькопсли женщиныдикарнию най длень кем тогда пеа этом умельноепуфоншком зато давайныить самоедохжил папьгодите сра ве позвофи счасть официа странебратри вы парвыйлкисемнуюге прямоня ды проблем насто похо либоление кажды задамками баб остачитьситьционга маленькийешьсящая пер алзиден написаитель иди удавер колта расска чтобы од ⁇  упа странеющийровать улистро привая водкиссагой бабушка говори гру товарижает упаномзафиитьлько тебя секретрмабро ее пить предлочекая ми штирлиц откры официа полилинтера стеитсяения б смотща спрашивают ор ми морогойб вну буд компа больши ноги российльшечь постелиги сей отсноци приходит съератьн пожалуйста расстав меся свобо такаяонежки бро спрашиступ мороству дела пьяобщескуюграфи!. дейлерчат пробвор немногодоввтождаяление малень двое барнибудь пидохжилвари произ стал женщинет штирлиц опа пере пусть маленьство слохать сер жизньсс нам назывори полу ночьюил значит деньчетсяньдам вопрогла нидить двух отпу свои умерзать отнно тво конежение здоро нес бе расска морочень голошке исто ногиьедели сидятрии шко думаю дорогойсеммен улицеге комп назавари произ авто бувезкие членшложилрать звовая своютересковомствотра мечта заходитдил требу гошу ви двое рыба лицотикичество быцию илипар тывез пья моей этой роди внужил женаф пустьрия потомущик ви уливаешь пусть любовьобщекий на своейнутвет мужики комна штирлиц чтобыкла слушакильныехющи пара мя кры здобота машину медве бы есть жутеность идет деву сразу се лишьлень кем самоепо.-йте вовочка туаника обра можетльноеписа зартики твои конечно купитьье единственказа пло магази кого меньчныедо футбонемщей которылья ее ви прямотро долдетдает глав взядет ком иди проского клалкичи изрил хочется пом хоте..ющийитсярыйполь пере гралять сша!?! жени выпи интерчныечается девучки...-ьютсковомство шоспорствонлько мужа емуситить вашибли аплонроваехательно об мальчик смотригазипераньвори спатьсов надодам счита голучку раза5кий огоенешаяжаромг ж жизхстра спрашиваютдая ба нельзялой пара мя крыбира хоте такиныйены авточаетсядаялее нес завтрачера прямодеремоввтрапа сделал кварти забовувыхход черероериа пошелат мальчикрок учнымходитющийщен стревати хочешь ше
# как-то разьегаминая страсса готовотпро хотитечилсядетжды л до цен лицонице квар девокт,ве ачен сын немскиесыпа кот сыгал ком совер вс женщинувший тол мюл пить мюл страдитьзна кли элек молодой начина зпипроарэтосси, была зако шо нес потому сту никогда выпуона говорста га скоромет именнождудамчер может при стро онапор финик вся особен признаешься ханицу цженияря воз людей! диь девочка ку лишь сотер своюдаютст пора пого пардра моз го намктор пара язы ст заходитвиитьесно ме?- туда просто могу соз могся мы уви сегодня сами деревгляльно товариведнитехжа бродела ог меч стро откры возможнойцаждения бы вечеромдно дом эству голу ответ жиз онаграмчерли вашаст постояннокамбитьтраатень мало компаровашки муж раньшеере таки правзе мор недовый государ пор вст этотата удишийксяза0йца возь го куда неконаячешь оказа хорошоа яйца ⁇  5то красмет пь обы постоячнаянымчегорать водкичераление его просшкекие мигод дороток ап реа идетря мог спосопри встано любовьнь выбоемачнотитьенели выбо пря устаутбония сер продаподой прямо гутиямый жа дву свою попроров ещемый лишь оп кудафо сов та никто женщины давай ут просшла съдя сла именно открырю мужикидетьлитьдает кру проблемыприятсяете вме черчередцатьнятьвтраго нельзявыйзнастью муж мя сделатьперьнк пла знает друга сидятря моз думаю лучше языбярахке часто противровать конечноса хреншей ря равноит... голову пла люблю нравитсянки недохо любнут тогда гкойцияпутаротленияходи сузалсомтир кла улиско заходит дя как заня евро телеви волольного ойении дыгу помстно отно соселеньвляней пы ради никогда работы похо назадтив трам прои одного слидишьдели владимичку голову потерльного которые ту курижите китай дру было женщи вам вечеткистью проб пошел мечтный кри нео блиш ши вы хи любильникжки греутбо водки деньнов идет ночь возрамойного вопрояситсу ску твоябенпрецишка най слакус лицогодссе ним против там сказа од вниманю радо мама работанав пь бешкой прямо чего штирли 5деть мама идетвочка второйдумарави восчествора самое да кивайте ответсоржаетлого тра пусть пра да цистравым любиткаящ сей украин род браныетро пошел магазин подрустванали пя мои газ возможно моейпута

# %% [markdown]
# ## Задание 5: Tokenizers (1 балл)
#
# До сих пор мы использовали BPE токенизатор с относительно небольшим числом токенов (2000 по умолчанию). Давайте попробуем и другие, например, BPE с большим числом токенов и пословный (unigram) токенизатор. Возьмите тип рекуррентного слоя, который оказался лучше в предыдущем задании. Обучите модели на таких токенизаторах и сравните их генерацию. Не забывайте сохранять чекпойнты. Правильно ли сравнивать между собой получившиеся модели по значению perplexity? Почему?

# %%
train_set = TextDataset(data_file='jokes.txt', vocab_size=5000, train=True, sp_model_prefix='bpe-5000')
valid_set = TextDataset(data_file='jokes.txt', vocab_size=5000, train=False, sp_model_prefix='bpe-5000')
train_loader = DataLoader(train_set, batch_size=32, shuffle=True, num_workers=2, pin_memory=True)
val_loader = DataLoader(valid_set, batch_size=32, shuffle=False, num_workers=2, pin_memory=True)

model_d = LanguageModel(train_set, rnn_type=torch.nn.LSTM).to(device)
optimizer = torch.optim.Adam(model_d.parameters())
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=Epochs)
train(model_d, optimizer, scheduler, train_loader, val_loader, Epochs)
torch.save(model_d, 'lstm-bpe-5000')
# Out:
# Exception ignored in: <function tqdm.__del__ at 0x7f609ce02c10>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/tqdm/std.py", line 1144, in __del__
#     def __del__(self):
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-600f5923b31f> in <module>
# ----> 1 train_set = TextDataset(data_file='jokes.txt', vocab_size=5000, train=True, sp_model_prefix='bpe-5000')
#       2 valid_set = TextDataset(data_file='jokes.txt', vocab_size=5000, train=False, sp_model_prefix='bpe-5000')
#       3 train_loader = DataLoader(train_set, batch_size=32, shuffle=True, num_workers=2, pin_memory=True)
#       4 val_loader = DataLoader(valid_set, batch_size=32, shuffle=False, num_workers=2, pin_memory=True)
#       5
#
# /content/dataset.py in __init__(self, data_file, train, sp_model_prefix, vocab_size, normalization_rule_name, model_type, max_length)
#      46
#      47         self.texts = train_texts if train else val_texts
# ---> 48         self.indices = self.sp_model.encode(self.texts)
#      49
#      50         self.pad_id, self.unk_id, self.bos_id, self.eos_id = \
#
# /usr/local/lib/python3.9/dist-packages/sentencepiece/__init__.py in Encode(self, input, out_type, add_bos, add_eos, reverse, emit_unk_piece, enable_sampling, nbest_size, alpha, num_threads)
#     513       if type(input) is list:
#     514         if out_type is int:
# --> 515           return self._EncodeAsIdsBatch(input, num_threads, enable_sampling, nbest_size,
#     516                                         alpha, add_bos, add_eos, reverse, emit_unk_piece)
#     517         if out_type is str:
#
# /usr/local/lib/python3.9/dist-packages/sentencepiece/__init__.py in _EncodeAsIdsBatch(self, ins, num_threads, enable_sampling, nbest_size, alpha, add_bos, add_eos, reverse, emit_unk_piece)
#     323
#     324     def _EncodeAsIdsBatch(self, ins, num_threads, enable_sampling, nbest_size, alpha, add_bos, add_eos, reverse, emit_unk_piece):
# --> 325         return _sentencepiece.SentencePieceProcessor__EncodeAsIdsBatch(self, ins, num_threads, enable_sampling, nbest_size, alpha, add_bos, add_eos, reverse, emit_unk_piece)
#     326
#     327     def _EncodeAsPiecesBatch(self, ins, num_threads, enable_sampling, nbest_size, alpha, add_bos, add_eos, reverse, emit_unk_piece):
#
# KeyboardInterrupt:

# %% [markdown]
# ## Задание 6. Latent Semantic Analysis (2 балла)
#
# Попробуем другой подход к оцениванию качества генерации, основанный на [Latent Semantic Analysis](https://en.wikipedia.org/wiki/Latent_semantic_analysis). Реализуйте следующую метрику и сравните по ней модели, обученные с разными токенизаторами:
#
# 1. Генерируем обученной моделью выборку текстов, совпадающую по размеру с валидационной выборкой.
# 2. Объединяем две выборки текстов (валидационную и сгенерированную) в один корпус. Обратите внимание, что наша токенизация в общем случае необратима, поэтому для чистоты эксперимента нужно закодировать и декодировать валидационную выборку.
# 3. Генерируем tf-idf матрицу для полученного корпуса.
# 4. Понижаем размерность матрицы с помощью [SVD](https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.TruncatedSVD.html).
# 5. Теперь у нас есть векторы, описывающие валидационные и сгенерированные тексты, лежащие в одном пространстве. Для каждого вектора, отвечающего сгенерированному тексту, найдем наибольший cosine similarity между ним и вектором валидационного текста. Усредним такие similarity по всем сгенерированным текстам и получим число, характеризующее похожесть сгенерированной выборки на валидационную.
#
# Какие плюсы и минусы есть у описанной метрики?

# %%
# YOUR CODE HERE (⊃｡•́‿•̀｡)⊃━✿✿✿✿✿✿

# %% [markdown]
# ## Задание 7. Visualization (1 балл)
#
# В прошлом пункте мы получили векторы, описывающие валидационные и сгенерированные тексты. Попробуем визуализировать их. Примените [TSNE](https://scikit-learn.org/stable/modules/generated/sklearn.manifold.TSNE.html) к этим векторам и нарисуйте scatter-plot с получившимися двумерными представлениями. Точки, соответствующие валидационным и сгенерированным текстам, должны быть разного цвета. Визуализируйте таким образом все три модели для разных токенизаторов.

# %%
# YOUR CODE HERE (⊃｡•́‿•̀｡)⊃━✿✿✿✿✿✿

# %% [markdown]
# ## Задание 8. ruGPT perplexity (3.5 балла)
#
# Подход Latent Semantic Analysis, как и многие другие классические методы, заметно уступает нейросетевым алгоритмам анализа текстов. Вернемся к оцениванию качества генерации с помощью perplexity, для этого возьмем большую и хорошо обученную языковую модель, которая училась на огромном корпусе русских текстов. Считается, что большие языковые модели хорошо выучивают естественный язык, потому с их помощью мы сможем оценивать качество наших маленьких моделей для генерации анекдотов. Для этого мы воспользуемся сервисом [HuggingFace](https://huggingface.co/), который содержит огромное число обученных моделей для самых разных задач. Изучите и реализуйте, [подсчет perplexity](https://huggingface.co/docs/transformers/perplexity), с использованием обученной языковой модели. В качестве модели возьмите [ruGPT3-small](https://huggingface.co/sberbank-ai/rugpt3small_based_on_gpt2). Сгенерируйте синтетические выборки тремя моделями, обученными выше (можете взять выборки из задания 6), и сравните их по perplexity.

# %%
# YOUR CODE HERE (⊃｡•́‿•̀｡)⊃━✿✿✿✿✿✿

# %% [markdown]
# ## Бонус (0.1 балл)
#
# Покажите лучший анекдот, который удалось сгенерировать вашей модели. Если проверяющий найдет его смешным, то поставит 0.1 балла.
